# %% [markdown]
# *Imports:*

# %%
import serial
import re
import cv2
import numpy as np
import time
from ultralytics import YOLO
from typing import Tuple

# %% [markdown]
# **Main Code Definitions:**

# %%
def clean_and_parse_data(raw_data: bytes) -> dict:
    # Decode the bytes to string, ignoring errors
    decoded_data = raw_data.decode('ascii', errors='ignore').strip()
    split_decoded_data = decoded_data.split(',')

    data_dict = {}
    for data_point in split_decoded_data:
        curr = data_point.split('=')
        if len(curr) == 2:  # Ensure that both key and value are present
            data_dict[curr[0].strip()] = curr[1].strip()  # Strip whitespace from keys and values
    return clean_uart_data(data_dict)

def clean_uart_data(data_dict: dict) -> dict:
    cleaned_dict = {}
    for key, value in data_dict.items():
        # Remove null characters from key and value
        clean_key = key.replace('\x00', '').strip()
        clean_value = value.replace('\x00', '').strip()
        
        # Add the cleaned key-value pair to the new dictionary if key is not empty
        if clean_key:
            cleaned_dict[clean_key] = clean_value
            
    return cleaned_dict

def find_center_of_frame(frame):
    height, width = frame.shape[:2]
    return width // 2, height // 2

def calculate_box_area(x1, y1, x2, y2):
    return (x2 - x1) * (y2 - y1)

def find_box_center(x1, y1, x2, y2):
    return int((x1 + x2) / 2), int((y1 + y2) / 2)

# %% [markdown]
# **Main Code:**

# %%
ser = serial.Serial(
    port='COM12',  
    baudrate=9600,
    parity=serial.PARITY_NONE,
    stopbits=serial.STOPBITS_ONE,
    bytesize=serial.EIGHTBITS,
    timeout=0
)

# Define the window size for the moving average & other parameters
WINDOW_SIZE = 1
x_values = np.zeros(WINDOW_SIZE)
y_values = np.zeros(WINDOW_SIZE)
index = 0

# Small waiting time to wait for everything in the STM to init
time.sleep(3)

model = YOLO('BestTennis.onnx', task = 'detect')
cap = cv2.VideoCapture(1)

actual_fps = cap.get(cv2.CAP_PROP_FPS)
print(f"Camera framerate set to: {actual_fps}")

ret, frame = cap.read()
set_point_x, set_point_y = find_center_of_frame(frame)

while True:
    ret, frame = cap.read()
    if not ret:
        break  # Exit loop if frame could not be read

    results = model(frame)
    largest_area = 0
    largest_box_center = None

    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            conf = box.conf[0]
            cls = box.cls[0]

            if conf < 0.5:
                continue
            
            area = calculate_box_area(x1, y1, x2, y2)
            
            if area > largest_area:
                largest_area = area
                largest_box_center = find_box_center(x1, y1, x2, y2)
            
            label = f"{model.names[int(cls)]} {conf:.2f}"
            color = (0, 255, 0)  # Green color for bounding box
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
            cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    if largest_box_center:
        cv2.circle(frame, largest_box_center, 5, (0, 0, 255), -1)  # Red dot
        cv2.putText(frame, f"Center: {largest_box_center}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        
    cv2.circle(frame, (set_point_x, set_point_y), 5, (255, 0, 0), -1)  # Blue dot
    cv2.putText(frame, f"Set Point: ({set_point_x}, {set_point_y})", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2)

    if largest_box_center:
        # Update the moving average arrays
        x_values[index] = largest_box_center[0]
        y_values[index] = largest_box_center[1]
        
        # Calculate the moving averages
        smoothed_x = int(np.mean(x_values))
        smoothed_y = int(np.mean(y_values))
        
        # Update the index for circular buffer
        index = (index + 1) % WINDOW_SIZE
        
        diff_x = smoothed_x - set_point_x
        diff_y = smoothed_y - set_point_y
        cv2.putText(frame, f"Difference: ({diff_x}, {diff_y})", (10, 90), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)
        str_to_send = f"a{smoothed_x:03d}{smoothed_y:03d}"
    else:
        str_to_send = "a320200"

    ser.write(str_to_send.encode())
    ser.flush()
    print(str_to_send)

    raw_data = ser.readline()
    parsed_data = clean_and_parse_data(raw_data)
    print(parsed_data)

    # Draw the dictionary values on the frame
    y_offset = 0
    for key, value in parsed_data.items():
        text = f"{key}: {value}"
        if(key == "Base Proj Point"): y_offset = 120
        elif(key == "Tilt Proj Point"): y_offset = 150
        elif(key == "Base PID Out"): y_offset = 180
        elif(key == "Tilt PID Out"): y_offset = 210
        cv2.putText(frame, text, (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
    text = "Sent: " + str_to_send
    cv2.putText(frame, text, (10, 240), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 255), 2)

    cv2.imshow("YOLOv8 Object Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
ser.close()
# Out:
# Camera framerate set to: 35.000035000035
# Loading BestTennis.onnx for ONNX Runtime inference...
#
# 0: 640x640 (no detections), 101.3ms
# Speed: 6.4ms preprocess, 101.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'\x04Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 102.1ms
# Speed: 7.5ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 104.8ms
# Speed: 6.0ms preprocess, 104.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 88.7ms
# Speed: 4.0ms preprocess, 88.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 86.0ms
# Speed: 3.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 97.3ms
# Speed: 4.0ms preprocess, 97.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 97.1ms
# Speed: 4.0ms preprocess, 97.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 89.1ms
# Speed: 5.0ms preprocess, 89.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 96.2ms
# Speed: 3.0ms preprocess, 96.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 87.5ms
# Speed: 6.0ms preprocess, 87.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 89.3ms
# Speed: 4.0ms preprocess, 89.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 96.0ms
# Speed: 3.0ms preprocess, 96.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 101.0ms
# Speed: 5.5ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 87.8ms
# Speed: 3.0ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 96.9ms
# Speed: 3.8ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 102.8ms
# Speed: 5.0ms preprocess, 102.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 1 ball, 93.2ms
# Speed: 3.0ms preprocess, 93.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# a388047
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 91.8ms
# Speed: 4.0ms preprocess, 91.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 98.3ms
# Speed: 4.0ms preprocess, 98.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 85.8ms
# Speed: 3.0ms preprocess, 85.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a498133
# {}
#
# 0: 640x640 1 ball, 105.0ms
# Speed: 4.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a494139
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 95.5ms
# Speed: 3.0ms preprocess, 95.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 1 ball, 89.6ms
# Speed: 6.0ms preprocess, 89.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a453158
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 93.3ms
# Speed: 3.0ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 95.0ms
# Speed: 6.0ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 103.4ms
# Speed: 5.5ms preprocess, 103.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 93.5ms
# Speed: 4.0ms preprocess, 93.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 106.8ms
# Speed: 6.0ms preprocess, 106.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 111.6ms
# Speed: 6.1ms preprocess, 111.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 116.8ms
# Speed: 4.0ms preprocess, 116.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 113.6ms
# Speed: 4.0ms preprocess, 113.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 108.5ms
# Speed: 4.0ms preprocess, 108.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 123.0ms
# Speed: 7.0ms preprocess, 123.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 111.9ms
# Speed: 4.0ms preprocess, 111.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 124.5ms
# Speed: 5.5ms preprocess, 124.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 116.8ms
# Speed: 4.5ms preprocess, 116.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 125.6ms
# Speed: 5.0ms preprocess, 125.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 109.0ms
# Speed: 7.0ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 119.0ms
# Speed: 6.0ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 105.6ms
# Speed: 4.0ms preprocess, 105.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 101.9ms
# Speed: 4.0ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 120.0ms
# Speed: 4.0ms preprocess, 120.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 117.1ms
# Speed: 7.0ms preprocess, 117.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 118.9ms
# Speed: 5.0ms preprocess, 118.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 108.4ms
# Speed: 7.0ms preprocess, 108.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 104.9ms
# Speed: 5.3ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 122.2ms
# Speed: 6.2ms preprocess, 122.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 125.3ms
# Speed: 3.4ms preprocess, 125.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 102.4ms
# Speed: 4.2ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 118.8ms
# Speed: 4.8ms preprocess, 118.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 113.0ms
# Speed: 4.8ms preprocess, 113.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 105.7ms
# Speed: 4.4ms preprocess, 105.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 114.2ms
# Speed: 4.0ms preprocess, 114.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 113.4ms
# Speed: 3.2ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 120.9ms
# Speed: 6.0ms preprocess, 120.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 113.0ms
# Speed: 3.1ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 97.6ms
# Speed: 5.0ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 110.8ms
# Speed: 3.5ms preprocess, 110.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a340231
# {}
#
# 0: 640x640 1 ball, 114.8ms
# Speed: 4.0ms preprocess, 114.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a311181
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 114.1ms
# Speed: 4.0ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a314172
# {}
#
# 0: 640x640 1 ball, 111.9ms
# Speed: 4.7ms preprocess, 111.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320176
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 115.4ms
# Speed: 4.0ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 103.5ms
# Speed: 4.0ms preprocess, 103.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 96.2ms
# Speed: 3.0ms preprocess, 96.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 99.1ms
# Speed: 5.5ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 101.1ms
# Speed: 4.0ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 124.2ms
# Speed: 5.0ms preprocess, 124.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 111.3ms
# Speed: 3.5ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 107.4ms
# Speed: 4.6ms preprocess, 107.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 112.0ms
# Speed: 6.7ms preprocess, 112.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 111.4ms
# Speed: 6.2ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 115.7ms
# Speed: 3.5ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 1 ball, 100.3ms
# Speed: 3.1ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a543082
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 112.6ms
# Speed: 5.0ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a558099
# {}
#
# 0: 640x640 1 ball, 109.1ms
# Speed: 3.5ms preprocess, 109.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# a568111
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 110.2ms
# Speed: 3.4ms preprocess, 110.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a573115
# {}
#
# 0: 640x640 1 ball, 107.7ms
# Speed: 4.3ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a577121
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 103.3ms
# Speed: 4.2ms preprocess, 103.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 111.8ms
# Speed: 6.0ms preprocess, 111.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 114.8ms
# Speed: 4.1ms preprocess, 114.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 111.3ms
# Speed: 4.1ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 107.4ms
# Speed: 3.7ms preprocess, 107.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a110162
# {}
#
# 0: 640x640 1 ball, 111.8ms
# Speed: 3.5ms preprocess, 111.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a143138
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 124.2ms
# Speed: 3.1ms preprocess, 124.2ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# a203111
# {}
#
# 0: 640x640 1 ball, 109.6ms
# Speed: 6.4ms preprocess, 109.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# a239110
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 (no detections), 118.2ms
# Speed: 4.0ms preprocess, 118.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 1 ball, 110.1ms
# Speed: 4.2ms preprocess, 110.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a295139
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 116.6ms
# Speed: 3.0ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a351182
# {}
#
# 0: 640x640 1 ball, 114.7ms
# Speed: 5.0ms preprocess, 114.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a383184
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 112.3ms
# Speed: 3.0ms preprocess, 112.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a441183
# {}
#
# 0: 640x640 1 ball, 111.7ms
# Speed: 5.4ms preprocess, 111.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a438172
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 103.0ms
# Speed: 3.3ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a391170
# {}
#
# 0: 640x640 1 ball, 106.3ms
# Speed: 4.0ms preprocess, 106.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a384170
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 108.6ms
# Speed: 7.2ms preprocess, 108.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a339171
# {}
#
# 0: 640x640 1 ball, 100.7ms
# Speed: 4.2ms preprocess, 100.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a325169
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 107.0ms
# Speed: 6.1ms preprocess, 107.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# a330168
# {}
#
# 0: 640x640 1 ball, 110.9ms
# Speed: 4.4ms preprocess, 110.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a365168
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 112.4ms
# Speed: 4.5ms preprocess, 112.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a387167
# {}
#
# 0: 640x640 1 ball, 103.5ms
# Speed: 4.6ms preprocess, 103.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a403166
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 112.2ms
# Speed: 3.1ms preprocess, 112.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a415162
# {}
#
# 0: 640x640 1 ball, 122.2ms
# Speed: 6.0ms preprocess, 122.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a430162
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 115.9ms
# Speed: 6.0ms preprocess, 115.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a443165
# {}
#
# 0: 640x640 1 ball, 107.5ms
# Speed: 6.1ms preprocess, 107.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a447169
# {'Base Proj Point': '494', 'Tilt Proj Point': '139', 'Base PID Out': '655', 'Tilt PID Out': '0'}
#
# 0: 640x640 1 ball, 105.2ms
# Speed: 5.6ms preprocess, 105.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a446173
# {}
#
# 0: 640x640 1 ball, 104.6ms
# Speed: 5.0ms preprocess, 104.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a440171
# {'Base Proj Point': '453', 'Tilt Proj Point': '158', 'Base PID Out': '5997', 'Tilt PID Out': '1287'}
#
# 0: 640x640 1 ball, 115.6ms
# Speed: 3.2ms preprocess, 115.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a431170
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '5997', 'Tilt PID Out': '1287'}
#
# 0: 640x640 1 ball, 100.7ms
# Speed: 4.2ms preprocess, 100.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# a422169
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '5997', 'Tilt PID Out': '1287'}
#
# 0: 640x640 1 ball, 114.1ms
# Speed: 4.2ms preprocess, 114.1ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
# a419169
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '3348', 'Tilt PID Out': '638'}
#
# 0: 640x640 1 ball, 101.6ms
# Speed: 4.4ms preprocess, 101.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a419169
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '3348', 'Tilt PID Out': '638'}
#
# 0: 640x640 1 ball, 113.8ms
# Speed: 4.0ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a409169
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '3348', 'Tilt PID Out': '638'}
#
# 0: 640x640 1 ball, 101.2ms
# Speed: 5.1ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a394173
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 115.0ms
# Speed: 5.2ms preprocess, 115.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# a378181
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 102.5ms
# Speed: 5.1ms preprocess, 102.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a364184
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 110.5ms
# Speed: 4.0ms preprocess, 110.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a346184
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 101.2ms
# Speed: 4.0ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a319175
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 108.4ms
# Speed: 4.0ms preprocess, 108.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a292168
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 95.4ms
# Speed: 5.1ms preprocess, 95.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a267159
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 110.2ms
# Speed: 4.0ms preprocess, 110.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a240155
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 91.3ms
# Speed: 6.0ms preprocess, 91.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# a195152
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 110.4ms
# Speed: 8.1ms preprocess, 110.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# a177155
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 105.2ms
# Speed: 5.4ms preprocess, 105.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a172155
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 105.5ms
# Speed: 7.0ms preprocess, 105.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 106.5ms
# Speed: 4.0ms preprocess, 106.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 108.8ms
# Speed: 4.3ms preprocess, 108.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a250147
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 110.2ms
# Speed: 7.6ms preprocess, 110.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 110.7ms
# Speed: 5.0ms preprocess, 110.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a363138
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 109.9ms
# Speed: 5.6ms preprocess, 109.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# a363138
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 109.1ms
# Speed: 5.5ms preprocess, 109.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 112.6ms
# Speed: 4.0ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a319122
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 101.6ms
# Speed: 4.0ms preprocess, 101.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a304123
# {'Base Proj Point': '311', 'Tilt Proj Point': '181', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 122.9ms
# Speed: 7.0ms preprocess, 122.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a291125
# {'Base Proj Point': '314', 'Tilt Proj Point': '172', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 118.9ms
# Speed: 4.0ms preprocess, 118.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# a277126
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 110.3ms
# Speed: 5.5ms preprocess, 110.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# a241125
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 106.2ms
# Speed: 3.0ms preprocess, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 112.5ms
# Speed: 3.1ms preprocess, 112.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 99.0ms
# Speed: 4.0ms preprocess, 99.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 101.2ms
# Speed: 3.3ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 109.6ms
# Speed: 4.0ms preprocess, 109.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 116.9ms
# Speed: 5.0ms preprocess, 116.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 102.8ms
# Speed: 4.0ms preprocess, 102.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '543', 'Tilt Proj Point': '82', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 114.0ms
# Speed: 4.0ms preprocess, 114.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '568', 'Tilt Proj Point': '111', 'Base PID Out': '10485', 'Tilt PID Out': '2673'}
#
# 0: 640x640 (no detections), 90.5ms
# Speed: 3.0ms preprocess, 90.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '573', 'Tilt Proj Point': '115', 'Base PID Out': '10485', 'Tilt PID Out': '2673'}
#
# 0: 640x640 (no detections), 89.8ms
# Speed: 3.0ms preprocess, 89.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '10485', 'Tilt PID Out': '2673'}
#
# 0: 640x640 (no detections), 107.8ms
# Speed: 5.7ms preprocess, 107.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '5703', 'Tilt PID Out': '1409'}
#
# 0: 640x640 1 ball, 112.1ms
# Speed: 3.0ms preprocess, 112.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '5703', 'Tilt PID Out': '1409'}
#
# 0: 640x640 (no detections), 96.8ms
# Speed: 3.0ms preprocess, 96.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '110', 'Tilt Proj Point': '162', 'Base PID Out': '5703', 'Tilt PID Out': '1409'}
#
# 0: 640x640 (no detections), 102.3ms
# Speed: 3.6ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '203', 'Tilt Proj Point': '111', 'Base PID Out': '5358', 'Tilt PID Out': '2673'}
#
# 0: 640x640 (no detections), 110.7ms
# Speed: 4.0ms preprocess, 110.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '239', 'Tilt Proj Point': '110', 'Base PID Out': '5358', 'Tilt PID Out': '2673'}
#
# 0: 640x640 (no detections), 113.5ms
# Speed: 3.7ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '295', 'Tilt Proj Point': '139', 'Base PID Out': '5358', 'Tilt PID Out': '2673'}
#
# 0: 640x640 (no detections), 102.9ms
# Speed: 5.1ms preprocess, 102.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '351', 'Tilt Proj Point': '182', 'Base PID Out': '4320', 'Tilt PID Out': '878'}
#
# 0: 640x640 (no detections), 103.0ms
# Speed: 4.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '383', 'Tilt Proj Point': '184', 'Base PID Out': '4320', 'Tilt PID Out': '878'}
#
# 0: 640x640 (no detections), 125.6ms
# Speed: 3.5ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '438', 'Tilt Proj Point': '172', 'Base PID Out': '4320', 'Tilt PID Out': '878'}
#
# 0: 640x640 (no detections), 104.4ms
# Speed: 3.3ms preprocess, 104.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '384', 'Tilt Proj Point': '170', 'Base PID Out': '2607', 'Tilt PID Out': '638'}
#
# 0: 640x640 (no detections), 104.1ms
# Speed: 4.1ms preprocess, 104.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '339', 'Tilt Proj Point': '171', 'Base PID Out': '2607', 'Tilt PID Out': '638'}
#
# 0: 640x640 (no detections), 100.3ms
# Speed: 5.0ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '330', 'Tilt Proj Point': '168', 'Base PID Out': '2607', 'Tilt PID Out': '638'}
#
# 0: 640x640 (no detections), 108.1ms
# Speed: 4.4ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '365', 'Tilt Proj Point': '168', 'Base PID Out': '1172', 'Tilt PID Out': '501'}
#
# 0: 640x640 (no detections), 99.9ms
# Speed: 3.3ms preprocess, 99.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '403', 'Tilt Proj Point': '166', 'Base PID Out': '1172', 'Tilt PID Out': '501'}
#
# 0: 640x640 (no detections), 104.3ms
# Speed: 3.0ms preprocess, 104.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '415', 'Tilt Proj Point': '162', 'Base PID Out': '1172', 'Tilt PID Out': '501'}
#
# 0: 640x640 1 ball, 109.9ms
# Speed: 5.2ms preprocess, 109.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a189249
# {'Base Proj Point': '430', 'Tilt Proj Point': '162', 'Base PID Out': '4157', 'Tilt PID Out': '645'}
#
# 0: 640x640 1 ball, 107.5ms
# Speed: 5.0ms preprocess, 107.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a185252
# {'Base Proj Point': '443', 'Tilt Proj Point': '165', 'Base PID Out': '4157', 'Tilt PID Out': '645'}
#
# 0: 640x640 1 ball, 113.1ms
# Speed: 3.0ms preprocess, 113.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a188245
# {'Base Proj Point': '446', 'Tilt Proj Point': '173', 'Base PID Out': '4157', 'Tilt PID Out': '645'}
#
# 0: 640x640 1 ball, 116.9ms
# Speed: 4.0ms preprocess, 116.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a185247
# {'Base Proj Point': '440', 'Tilt Proj Point': '171', 'Base PID Out': '3225', 'Tilt PID Out': '281'}
#
# 0: 640x640 1 ball, 102.2ms
# Speed: 3.6ms preprocess, 102.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a220247
# {'Base Proj Point': '422', 'Tilt Proj Point': '169', 'Base PID Out': '3225', 'Tilt PID Out': '281'}
#
# 0: 640x640 1 ball, 116.7ms
# Speed: 4.0ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a269246
# {'Base Proj Point': '419', 'Tilt Proj Point': '169', 'Base PID Out': '3225', 'Tilt PID Out': '281'}
#
# 0: 640x640 1 ball, 101.9ms
# Speed: 5.3ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a314236
# {'Base Proj Point': '409', 'Tilt Proj Point': '169', 'Base PID Out': '1782', 'Tilt PID Out': '488'}
#
# 0: 640x640 1 ball, 106.3ms
# Speed: 5.0ms preprocess, 106.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a333227
# {'Base Proj Point': '378', 'Tilt Proj Point': '181', 'Base PID Out': '1782', 'Tilt PID Out': '488'}
#
# 0: 640x640 1 ball, 96.6ms
# Speed: 3.0ms preprocess, 96.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a343227
# {'Base Proj Point': '364', 'Tilt Proj Point': '184', 'Base PID Out': '1782', 'Tilt PID Out': '488'}
#
# 0: 640x640 1 ball, 111.5ms
# Speed: 4.0ms preprocess, 111.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a339230
# {'Base Proj Point': '319', 'Tilt Proj Point': '175', 'Base PID Out': '2494', 'Tilt PID Out': '278'}
#
# 0: 640x640 1 ball, 107.7ms
# Speed: 3.0ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a336230
# {'Base Proj Point': '267', 'Tilt Proj Point': '159', 'Base PID Out': '2494', 'Tilt PID Out': '278'}
#
# 0: 640x640 1 ball, 112.6ms
# Speed: 6.0ms preprocess, 112.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# a335229
# {'Base Proj Point': '240', 'Tilt Proj Point': '155', 'Base PID Out': '2494', 'Tilt PID Out': '278'}
#
# 0: 640x640 1 ball, 111.2ms
# Speed: 4.0ms preprocess, 111.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a329228
# {'Base Proj Point': '177', 'Tilt Proj Point': '155', 'Base PID Out': '6376', 'Tilt PID Out': '966'}
#
# 0: 640x640 1 ball, 102.2ms
# Speed: 6.5ms preprocess, 102.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# a315224
# {'Base Proj Point': '172', 'Tilt Proj Point': '155', 'Base PID Out': '6376', 'Tilt PID Out': '966'}
#
# 0: 640x640 1 ball, 119.8ms
# Speed: 4.2ms preprocess, 119.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a277217
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '6376', 'Tilt PID Out': '966'}
#
# 0: 640x640 1 ball, 109.3ms
# Speed: 5.5ms preprocess, 109.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a244207
# {'Base Proj Point': '250', 'Tilt Proj Point': '147', 'Base PID Out': '757', 'Tilt PID Out': '874'}
#
# 0: 640x640 1 ball, 105.9ms
# Speed: 4.0ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a220203
# {'Base Proj Point': '363', 'Tilt Proj Point': '138', 'Base PID Out': '757', 'Tilt PID Out': '874'}
#
# 0: 640x640 1 ball, 106.6ms
# Speed: 8.1ms preprocess, 106.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a215201
# {'Base Proj Point': '363', 'Tilt Proj Point': '138', 'Base PID Out': '757', 'Tilt PID Out': '874'}
#
# 0: 640x640 1 ball, 101.4ms
# Speed: 3.0ms preprocess, 101.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a210201
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '2058', 'Tilt PID Out': '819'}
#
# 0: 640x640 1 ball, 107.1ms
# Speed: 6.5ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a231199
# {'Base Proj Point': '304', 'Tilt Proj Point': '123', 'Base PID Out': '2058', 'Tilt PID Out': '819'}
#
# 0: 640x640 1 ball, 118.6ms
# Speed: 4.0ms preprocess, 118.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
# a236199
# {'Base Proj Point': '291', 'Tilt Proj Point': '125', 'Base PID Out': '2058', 'Tilt PID Out': '819'}
#
# 0: 640x640 1 ball, 92.0ms
# Speed: 5.3ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a236198
# {'Base Proj Point': '241', 'Tilt Proj Point': '125', 'Base PID Out': '3840', 'Tilt PID Out': '2260'}
#
# 0: 640x640 2 balls, 106.9ms
# Speed: 5.6ms preprocess, 106.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a236196
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '3840', 'Tilt PID Out': '2260'}
#
# 0: 640x640 1 ball, 121.7ms
# Speed: 5.3ms preprocess, 121.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# a232191
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '3840', 'Tilt PID Out': '2260'}
#
# 0: 640x640 1 ball, 111.7ms
# Speed: 4.2ms preprocess, 111.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# a224187
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '2242', 'Tilt PID Out': '1179'}
#
# 0: 640x640 1 ball, 122.2ms
# Speed: 4.0ms preprocess, 122.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a216184
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '2242', 'Tilt PID Out': '1179'}
#
# 0: 640x640 1 ball, 108.6ms
# Speed: 4.3ms preprocess, 108.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# a216178
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '2242', 'Tilt PID Out': '1179'}
#
# 0: 640x640 1 ball, 117.7ms
# Speed: 6.4ms preprocess, 117.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a223177
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 104.6ms
# Speed: 4.1ms preprocess, 104.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a235178
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 112.5ms
# Speed: 6.0ms preprocess, 112.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a234177
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 97.6ms
# Speed: 3.0ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a231172
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 105.1ms
# Speed: 4.0ms preprocess, 105.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a234169
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 103.0ms
# Speed: 4.6ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a219170
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 110.4ms
# Speed: 5.2ms preprocess, 110.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a199162
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 119.9ms
# Speed: 3.4ms preprocess, 119.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a186155
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 103.9ms
# Speed: 4.0ms preprocess, 103.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a168130
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 106.4ms
# Speed: 4.0ms preprocess, 106.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a166115
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 106.9ms
# Speed: 4.4ms preprocess, 106.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a168116
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 2 balls, 112.8ms
# Speed: 4.8ms preprocess, 112.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# a153113
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 103.2ms
# Speed: 5.1ms preprocess, 103.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a105122
# {'Base Proj Point': '189', 'Tilt Proj Point': '249', 'Base PID Out': '5917', 'Tilt PID Out': '1494'}
#
# 0: 640x640 1 ball, 100.1ms
# Speed: 4.4ms preprocess, 100.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a092127
# {'Base Proj Point': '188', 'Tilt Proj Point': '245', 'Base PID Out': '5917', 'Tilt PID Out': '1494'}
#
# 0: 640x640 1 ball, 111.9ms
# Speed: 4.1ms preprocess, 111.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a041151
# {'Base Proj Point': '220', 'Tilt Proj Point': '247', 'Base PID Out': '5917', 'Tilt PID Out': '1494'}
#
# 0: 640x640 1 ball, 113.0ms
# Speed: 4.5ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a028148
# {'Base Proj Point': '269', 'Tilt Proj Point': '246', 'Base PID Out': '1270', 'Tilt PID Out': '602'}
#
# 0: 640x640 1 ball, 109.3ms
# Speed: 5.0ms preprocess, 109.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# a069112
# {'Base Proj Point': '333', 'Tilt Proj Point': '227', 'Base PID Out': '1270', 'Tilt PID Out': '602'}
#
# 0: 640x640 1 ball, 110.2ms
# Speed: 4.0ms preprocess, 110.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a155082
# {'Base Proj Point': '343', 'Tilt Proj Point': '227', 'Base PID Out': '1270', 'Tilt PID Out': '602'}
#
# 0: 640x640 2 balls, 109.0ms
# Speed: 5.3ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a359050
# {'Base Proj Point': '336', 'Tilt Proj Point': '230', 'Base PID Out': '2369', 'Tilt PID Out': '180'}
#
# 0: 640x640 1 ball, 113.4ms
# Speed: 3.5ms preprocess, 113.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '335', 'Tilt Proj Point': '229', 'Base PID Out': '2369', 'Tilt PID Out': '180'}
#
# 0: 640x640 1 ball, 113.4ms
# Speed: 3.5ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a557033
# {'Base Proj Point': '315', 'Tilt Proj Point': '224', 'Base PID Out': '2369', 'Tilt PID Out': '180'}
#
# 0: 640x640 1 ball, 105.0ms
# Speed: 5.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '244', 'Tilt Proj Point': '207', 'Base PID Out': '4048', 'Tilt PID Out': '235'}
#
# 0: 640x640 (no detections), 110.3ms
# Speed: 4.2ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '220', 'Tilt Proj Point': '203', 'Base PID Out': '4048', 'Tilt PID Out': '235'}
#
# 0: 640x640 (no detections), 106.9ms
# Speed: 3.0ms preprocess, 106.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '210', 'Tilt Proj Point': '201', 'Base PID Out': '4048', 'Tilt PID Out': '235'}
#
# 0: 640x640 1 ball, 108.9ms
# Speed: 5.0ms preprocess, 108.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a585033
# {'Base Proj Point': '236', 'Tilt Proj Point': '199', 'Base PID Out': '2484', 'Tilt PID Out': '100'}
#
# 0: 640x640 1 ball, 114.1ms
# Speed: 3.1ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a552034
# {'Base Proj Point': '236', 'Tilt Proj Point': '198', 'Base PID Out': '2484', 'Tilt PID Out': '100'}
#
# 0: 640x640 (no detections), 109.0ms
# Speed: 4.0ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '236', 'Tilt Proj Point': '196', 'Base PID Out': '2484', 'Tilt PID Out': '100'}
#
# 0: 640x640 1 ball, 94.3ms
# Speed: 4.0ms preprocess, 94.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a368100
# {'Base Proj Point': '224', 'Tilt Proj Point': '187', 'Base PID Out': '2799', 'Tilt PID Out': '398'}
#
# 0: 640x640 1 ball, 119.9ms
# Speed: 6.1ms preprocess, 119.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a284184
# {'Base Proj Point': '216', 'Tilt Proj Point': '184', 'Base PID Out': '2799', 'Tilt PID Out': '398'}
#
# 0: 640x640 1 ball, 105.2ms
# Speed: 3.0ms preprocess, 105.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a198259
# {'Base Proj Point': '216', 'Tilt Proj Point': '178', 'Base PID Out': '2799', 'Tilt PID Out': '398'}
#
# 0: 640x640 1 ball, 108.6ms
# Speed: 4.0ms preprocess, 108.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a113318
# {'Base Proj Point': '223', 'Tilt Proj Point': '177', 'Base PID Out': '2593', 'Tilt PID Out': '514'}
#
# 0: 640x640 1 ball, 109.0ms
# Speed: 4.6ms preprocess, 109.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '234', 'Tilt Proj Point': '177', 'Base PID Out': '2593', 'Tilt PID Out': '514'}
#
# 0: 640x640 1 ball, 103.7ms
# Speed: 6.0ms preprocess, 103.7ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# a070221
# {'Base Proj Point': '234', 'Tilt Proj Point': '169', 'Base PID Out': '2593', 'Tilt PID Out': '514'}
#
# 0: 640x640 1 ball, 116.4ms
# Speed: 4.0ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a163105
# {'Base Proj Point': '219', 'Tilt Proj Point': '170', 'Base PID Out': '2733', 'Tilt PID Out': '557'}
#
# 0: 640x640 (no detections), 105.2ms
# Speed: 4.2ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '186', 'Tilt Proj Point': '155', 'Base PID Out': '2733', 'Tilt PID Out': '557'}
#
# 0: 640x640 (no detections), 102.9ms
# Speed: 4.0ms preprocess, 102.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '166', 'Tilt Proj Point': '115', 'Base PID Out': '2733', 'Tilt PID Out': '557'}
#
# 0: 640x640 (no detections), 96.6ms
# Speed: 8.3ms preprocess, 96.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '168', 'Tilt Proj Point': '116', 'Base PID Out': '4687', 'Tilt PID Out': '2034'}
#
# 0: 640x640 (no detections), 103.0ms
# Speed: 5.1ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '105', 'Tilt Proj Point': '122', 'Base PID Out': '4687', 'Tilt PID Out': '2034'}
#
# 0: 640x640 1 ball, 114.2ms
# Speed: 5.0ms preprocess, 114.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# a460028
# ...
#
# 0: 640x640 (no detections), 115.1ms
# Speed: 5.1ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '6154'}
#
# 0: 640x640 (no detections), 111.4ms
# Speed: 4.0ms preprocess, 111.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Tilt PID Out': '2834'}
#
# 0: 640x640 (no detections), 105.0ms
# Speed: 6.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '6154', 'Tilt PID Out': '2834'}
#
# 0: 640x640 (no detections), 115.5ms
# Speed: 3.0ms preprocess, 115.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '6154'}
#
# 0: 640x640 (no detections), 111.7ms
# Speed: 5.3ms preprocess, 111.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Tilt PID Out': '2834'}
#
# 0: 640x640 (no detections), 111.4ms
# Speed: 3.4ms preprocess, 111.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 100.3ms
# Speed: 4.0ms preprocess, 100.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200'}
#
# 0: 640x640 (no detections), 110.5ms
# Speed: 4.1ms preprocess, 110.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 105.1ms
# Speed: 4.0ms preprocess, 105.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686'}
#
# 0: 640x640 (no detections), 110.0ms
# Speed: 3.0ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 117.2ms
# Speed: 5.4ms preprocess, 117.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 108.1ms
# Speed: 4.3ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200'}
#
# 0: 640x640 (no detections), 116.0ms
# Speed: 3.0ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 118.4ms
# Speed: 3.1ms preprocess, 118.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686'}
#
# 0: 640x640 (no detections), 102.5ms
# Speed: 6.8ms preprocess, 102.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'t': '49'}
#
# 0: 640x640 (no detections), 104.8ms
# Speed: 5.0ms preprocess, 104.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 112.7ms
# Speed: 4.0ms preprocess, 112.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '6'}
#
# 0: 640x640 (no detections), 110.9ms
# Speed: 4.0ms preprocess, 110.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 109.8ms
# Speed: 6.0ms preprocess, 109.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686'}
#
# 0: 640x640 (no detections), 100.3ms
# Speed: 3.5ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 114.6ms
# Speed: 5.2ms preprocess, 114.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 115.0ms
# Speed: 4.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686'}
#
# 0: 640x640 (no detections), 116.2ms
# Speed: 5.0ms preprocess, 116.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 105.0ms
# Speed: 3.8ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 106.9ms
# Speed: 3.2ms preprocess, 106.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686'}
#
# 0: 640x640 (no detections), 107.3ms
# Speed: 4.8ms preprocess, 107.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 112.7ms
# Speed: 4.1ms preprocess, 112.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 113.8ms
# Speed: 4.8ms preprocess, 113.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686'}
#
# 0: 640x640 (no detections), 105.9ms
# Speed: 4.0ms preprocess, 105.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'PID Out': '49'}
#
# 0: 640x640 (no detections), 99.5ms
# Speed: 4.3ms preprocess, 99.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 111.8ms
# Speed: 6.3ms preprocess, 111.8ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': ''}
#
# 0: 640x640 1 ball, 110.9ms
# Speed: 5.0ms preprocess, 110.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 (no detections), 96.8ms
# Speed: 4.0ms preprocess, 96.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 111.0ms
# Speed: 4.6ms preprocess, 111.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686'}
#
# 0: 640x640 1 ball, 101.0ms
# Speed: 4.4ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 89.6ms
# Speed: 3.0ms preprocess, 89.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686'}
#
# 0: 640x640 (no detections), 100.5ms
# Speed: 3.2ms preprocess, 100.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 107.9ms
# Speed: 5.1ms preprocess, 107.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '4'}
#
# 0: 640x640 1 ball, 114.2ms
# Speed: 4.0ms preprocess, 114.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a024127
# {}
#
# 0: 640x640 1 ball, 105.7ms
# Speed: 5.5ms preprocess, 105.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 114.7ms
# Speed: 4.4ms preprocess, 114.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '24', 'Tilt Proj Point': '127', 'Base PID Out': '686'}
#
# 0: 640x640 (no detections), 114.1ms
# Speed: 5.0ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 100.5ms
# Speed: 3.0ms preprocess, 100.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 116.7ms
# Speed: 4.0ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200'}
#
# 0: 640x640 1 ball, 111.6ms
# Speed: 4.2ms preprocess, 111.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a420067
# {'ase PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 105.5ms
# Speed: 5.5ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a407070
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 100.6ms
# Speed: 3.1ms preprocess, 100.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a417086
# {'Base Proj Point': '407', 'Tilt Proj Point': '70'}
#
# 0: 640x640 1 ball, 116.8ms
# Speed: 8.5ms preprocess, 116.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a423097
# {'Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 1 ball, 109.4ms
# Speed: 5.0ms preprocess, 109.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a428104
# {'Base Proj Point': '417', 'Tilt Proj Point': '86', 'Base PID Out': '4559', 'Tilt PID Out': '34'}
#
# 0: 640x640 1 ball, 112.1ms
# Speed: 6.3ms preprocess, 112.1ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {}
#
# 0: 640x640 1 ball, 113.8ms
# Speed: 6.6ms preprocess, 113.8ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# a411207
# {'Base Proj Point': '428', 'Tilt Proj Point': '104', 'Base PID Out': '4559', 'Tilt PID Out': '3411'}
#
# 0: 640x640 1 ball, 115.5ms
# Speed: 5.5ms preprocess, 115.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a414310
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '4559'}
#
# 0: 640x640 (no detections), 113.4ms
# Speed: 3.9ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Out': '3411'}
#
# 0: 640x640 (no detections), 111.3ms
# Speed: 4.0ms preprocess, 111.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '414', 'Tilt Proj Point': '310', 'Base PID Out': '2453', 'Tilt PID Out': '5160'}
#
# 0: 640x640 1 ball, 119.8ms
# Speed: 4.2ms preprocess, 119.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a417305
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '2453'}
#
# 0: 640x640 1 ball, 122.1ms
# Speed: 5.0ms preprocess, 122.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# a422089
# {'Tilt PID Out': '5160'}
#
# 0: 640x640 (no detections), 111.5ms
# Speed: 5.0ms preprocess, 111.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '417', 'Tilt Proj Point': '305', 'Base PID Out': '2453', 'Tilt PID Out': '5160'}
#
# 0: 640x640 (no detections), 105.5ms
# Speed: 7.2ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '422', 'Tilt Proj Point': '89', 'Base PID Out': '2834', 'Tilt PID Out': '5124'}
#
# 0: 640x640 (no detections), 110.6ms
# Speed: 4.3ms preprocess, 110.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200'}
#
# 0: 640x640 (no detections), 117.4ms
# Speed: 6.0ms preprocess, 117.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base PID Out': '2834', 'Tilt PID Out': '5124'}
#
# 0: 640x640 1 ball, 110.0ms
# Speed: 4.2ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a428124
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '2834'}
#
# 0: 640x640 1 ball, 111.0ms
# Speed: 5.0ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a432237
# {'PID Out': '5124'}
#
# 0: 640x640 1 ball, 107.5ms
# Speed: 5.0ms preprocess, 107.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# a432333
# {'Base Proj Point': '428', 'Tilt Proj Point': '124', 'Base PID Out': '2910', 'Tilt PID Out': '471'}
#
# 0: 640x640 1 ball, 119.4ms
# Speed: 5.0ms preprocess, 119.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a434337
# {'Base Proj Point': '432', 'Tilt Proj Point': '237', 'Base PID Out': '2910', 'Tilt PID Out': '471'}
#
# 0: 640x640 1 ball, 114.5ms
# Speed: 4.0ms preprocess, 114.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a434339
# {'Base Proj Point': '434', 'Tilt Proj Point': '337', 'Base PID Out': '2'}
#
# 0: 640x640 1 ball, 114.2ms
# Speed: 5.2ms preprocess, 114.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a436339
# {'Tilt PID Out': '471'}
#
# 0: 640x640 1 ball, 124.0ms
# Speed: 4.0ms preprocess, 124.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a436339
# {'Base Proj Point': '434', 'Tilt Proj Point': '339', 'Base PID Out': '3026', 'Tilt PID Out': '5393'}
#
# 0: 640x640 2 balls, 109.2ms
# Speed: 6.0ms preprocess, 109.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# a437226
# {'Base Proj Point': '436', 'Tilt Proj Point': '339'}
#
# 0: 640x640 2 balls, 113.4ms
# Speed: 4.4ms preprocess, 113.4ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
# a436072
# {'ID Out': '3026', 'Tilt PID Out': '5393'}
#
# 0: 640x640 (no detections), 113.0ms
# Speed: 5.0ms preprocess, 113.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '437', 'Tilt Proj Point': '226', 'Base PID Out': '3026', 'Tilt PID Out': '5393'}
#
# 0: 640x640 (no detections), 107.1ms
# Speed: 6.1ms preprocess, 107.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '2959'}
#
# 0: 640x640 (no detections), 114.4ms
# Speed: 6.3ms preprocess, 114.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Tilt PID Out': '2228'}
#
# 0: 640x640 (no detections), 109.3ms
# Speed: 6.0ms preprocess, 109.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '2959', 'Tilt PID Out': '2228'}
#
# 0: 640x640 (no detections), 105.6ms
# Speed: 8.2ms preprocess, 105.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200'}
#
# 0: 640x640 1 ball, 106.3ms
# Speed: 4.5ms preprocess, 106.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Out': '2959', 'Tilt PID Out': '2228'}
#
# 0: 640x640 (no detections), 119.0ms
# Speed: 7.0ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686'}
#
# 0: 640x640 1 ball, 105.4ms
# Speed: 3.4ms preprocess, 105.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'t': '49'}
#
# 0: 640x640 (no detections), 109.8ms
# Speed: 5.7ms preprocess, 109.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200', 'Base PID Out': '686', 'Tilt PID Out': '49'}
#
# 0: 640x640 (no detections), 94.8ms
# Speed: 4.2ms preprocess, 94.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# a320200
# {'Base Proj Point': '320', 'Tilt Proj Point': '200'}

# %%
ser.close()

# %%
import torch
from ultralytics import YOLO
import os

def export_yolo_to_onnx(pt_file, onnx_file):
    # Load the model
    model = YOLO(pt_file)

    # Export the model
    try:
        model.export(format="onnx", opset=12, simplify=True)
        print(f"Model exported successfully to {onnx_file}")
    except Exception as e:
        print(f"Error exporting model: {str(e)}")

# Specify the input .pt file and output .onnx file
pt_file = "BestTennis.pt"
onnx_file = "BestTennis.onnx"

# Call the function
export_yolo_to_onnx(pt_file, onnx_file)
# Out:
# Ultralytics YOLOv8.2.80  Python-3.11.2 torch-2.3.0+cpu CPU (11th Gen Intel Core(TM) i3-1115G4 3.00GHz)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'BestTennis.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['onnxslim>=0.1.31'] not found, attempting AutoUpdate...
# Collecting onnxslim>=0.1.31
#   Downloading onnxslim-0.1.34-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: onnx in c:\users\sandr\appdata\local\programs\python\python311\lib\site-packages (from onnxslim>=0.1.31) (1.16.1)
# Requirement already satisfied: sympy in c:\users\sandr\appdata\local\programs\python\python311\lib\site-packages (from onnxslim>=0.1.31) (1.13.2)
# Requirement already satisfied: packaging in c:\users\sandr\appdata\local\programs\python\python311\lib\site-packages (from onnxslim>=0.1.31) (23.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\sandr\appdata\local\programs\python\python311\lib\site-packages (from onnx->onnxslim>=0.1.31) (1.24.2)
# Requirement already satisfied: protobuf>=3.20.2 in c:\users\sandr\appdata\local\programs\python\python311\lib\site-packages (from onnx->onnxslim>=0.1.31) (5.28.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sandr\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxslim>=0.1.31) (1.3.0)
# Downloading onnxslim-0.1.34-py3-none-any.whl (140 kB)
# Installing collected packages: onnxslim
# Successfully installed onnxslim-0.1.34
#
# requirements: AutoUpdate success  3.4s, installed 1 package: ['onnxslim>=0.1.31']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.16.1 opset 12...
# ONNX: slimming with onnxslim 0.1.34...
# ONNX: export success  6.5s, saved as 'BestTennis.onnx' (11.7 MB)
#
# Export complete (10.4s)
# Results saved to C:\Users\sandr\OneDrive\Desktop\Junior Project\PythonProgram
# Predict:         yolo predict task=detect model=BestTennis.onnx imgsz=640
# Validate:        yolo val task=detect model=BestTennis.onnx imgsz=640 data=/content/Tennis-Ball-Obj-Det-1/data.yaml
# Visualize:       https://netron.app
# Model exported successfully to BestTennis.onnx
